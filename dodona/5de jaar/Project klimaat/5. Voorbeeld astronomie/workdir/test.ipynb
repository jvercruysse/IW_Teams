# %%
import pandas as pd
inhoud = pd.read_csv('stereigenschappen 1.csv', sep=';', index_col=False)
inhoud
# Out:
#    Sklasse Straal Massa   Licht            Temp                 Voorbeeld
# 0       O5    8,5    20   91000           34000             Zeta Ophiuchi
# 1       B0    6,5    15   20400           31000               Tau Scorpii
# 2       B7    3,1   3,8     288           12460                 Regulus A
# 3       A0    2,5   3,2      80           10800  Alpha Coronae Borealis A
# 4       A7    1,3   1,8    10,6            7550                    Altair
# 5   F0.1,3    1,7     6    7240  Gamma Virginis                       NaN
# 6       F6    1,3  1,24     2,8            6620       Tabit (Pi3 Orionis)
# 7       G0   1,05  1,10    1,26            5920      Beta Comae Berenices
# 8       G2      1     1       1            5780                       Zon
# 9       G5   0,93  0,93    0,79            5610              Alpha Mensae
# 10      K0   0,85  0,78    0,40            5240             70 Ophiuchi A
# 11      K5   0,74  0,69    0,16            4410                61 Cygni A
# ...

# %%
print(inhoud['Massa'])
print(inhoud['Temp'])
# Out:
# 0       20
# 1       15
# 2      3,8
# 3      3,2
# 4      1,8
# 5        6
# 6     1,24
# 7     1,10
# 8        1
# 9     0,93
# 10    0,78
# 11    0,69
# 12    0,60
# 13    0,21
# 14    0,11
# Name: Massa, dtype: object
# 0              34000
# 1              31000
# 2              12460
# 3              10800
# 4               7550
# 5     Gamma Virginis
# 6               6620
# 7               5920
# 8               5780
# 9               5610
# 10              5240
# 11              4410
# 12              3800
# 13              3120
# 14              2800
# Name: Temp, dtype: object
